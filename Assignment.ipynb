# %% [markdown]
# # The Depression Dataset
# ### *Misha Sharma - 100826646*

# %% [markdown]
# ## Introduction
#
# The data being provided in this notebook can be an upsetting topic for some people. Today, we are exploring the Depression Dataset. This dataset is provided on Kaggle and was created by Möbius, helping researchers to automatically detect the depression status of a person. Depression can be caused due to many reasons, such as education, school, poor choice of friends, etc. For these reasons, characteristic symptoms like sadness, the feeling of emptiness, and anxiety can arise. Throughout this report, we will be displaying, cleaning, plotting the clean dataset. The dataset we will be looking through canbe suitable (but not limited to) for the following applications as stated by the writer, (i) Use machine learning for depression states classification, (ii) MADRS score prediction based on motor activity data, (iii) Sleep pattern analysis of depressed v.s. non-depressed participants. We will be analyzing if there is a significant difference between the distribution of males and females in the age groups provided by the dataset.

# %% [markdown]
# ## Analyses
# ### Loading Data

# %%
import pandas as pd

# Load the dataset into jupyter notebook using pandas library
# We are calling our excel file df, df stands for dataframe
df = pd.read_csv('scores.csv')

# %% [markdown]
# We use the pandas library to work with our dataset. This library helps us analyze, clean, explore, and manipulate data.

# %% [markdown]
# ### Displaying Data

# %% [markdown]
# #### This is the dataset we are analyzing. It shows the number of patients, # of days of measurement, gender, age, etc. In the original dataset there are condition patients who suffer from depression and control patients who are healthy and do not suffer from depression. For this assignment, we will be analyzing the patients who suffer with depression for accurate results.

# %%
# Display the first 23 rows of the dataset to give a general idea of the data being studied 
df.head(23)
# Out:
#           number  days  gender    age  afftype  melanch  inpatient    edu  \
# 0    condition_1    11       2  35-39      2.0      2.0        2.0   6-10
# 1    condition_2    18       2  40-44      1.0      2.0        2.0   6-10
# 2    condition_3    13       1  45-49      2.0      2.0        2.0   6-10
# 3    condition_4    13       2  25-29      2.0      2.0        2.0  11-15
# 4    condition_5    13       2  50-54      2.0      2.0        2.0  11-15
# 5    condition_6     7       1  35-39      2.0      2.0        2.0   6-10
# 6    condition_7    11       1  20-24      1.0      NaN        2.0  11-15
# 7    condition_8     5       2  25-29      2.0      NaN        2.0  11-15
# 8    condition_9    13       2  45-49      1.0      NaN        2.0   6-10
# 9   condition_10     9       2  45-49      2.0      2.0        2.0   6-10
# 10  condition_11    14       1  45-49      2.0      2.0        2.0   6-10
# 11  condition_12    12       2  40-44      1.0      2.0        2.0   6-10
# ...

# %% [markdown]
# ### Cleaning Data
# ##### We are exploring the relationship between the 2 age groups (20-35) and (35-70) and the distribution of male and female in both age groups provided. Right now, we just cleaned the dataset and removed unnecessary columns that we are not analyzing.

# %%
import pandas as pd

# Load your dataset into the 'df' DataFrame
df = pd.read_csv('scores.csv')

# Create a new DataFrame with only 'gender' and 'age'. 'cleaned_df' means we are cleaning the data and only displaying the 'gender' and 'age' columns
cleaned_df = df[['gender', 'age']].copy()

# Display the 23 rows of the cleaned DataFrame
cleaned_df.head(23)
# Out:
#     gender    age
# 0        2  35-39
# 1        2  40-44
# 2        1  45-49
# 3        2  25-29
# 4        2  50-54
# 5        1  35-39
# 6        1  20-24
# 7        2  25-29
# 8        2  45-49
# 9        2  45-49
# 10       1  45-49
# 11       2  40-44
# 12       2  35-39
# 13       1  60-64
# 14       2  55-59
# 15       1  45-49
# 16       1  50-54
# 17       2  40-44
# 18       2  50-54
# 19       1  30-34
# 20       2  35-39
# 21       1  65-69
# 22       1  30-34

# %% [markdown]
# ### Displaying Summary Statistics
# #### Here we are displaying the statistics of 'gender' and 'age'

# %%
# Create a new  cleaned DataFrame with only 'gender' and 'age'
cleaned_df = df[['gender', 'age']].copy()

# Use describe() for  describing the summary statistics
describe_stats = cleaned_df.describe(include='all')

# Display the summary statistics by using print
print(describe_stats)
# Out:
#            gender    age
# count   55.000000     55
# unique        NaN     10
# top           NaN  50-54
# freq          NaN      9
# mean     1.454545    NaN
# std      0.502519    NaN
# min      1.000000    NaN
# 25%      1.000000    NaN
# 50%      1.000000    NaN
# 75%      2.000000    NaN
# max      2.000000    NaN

# %% [markdown]
# You can see above that most values in the 'age' coloumn are NaN. This is because we do not have the specific age of a person. We are only given an interval to pull out information from. Thus, the empty values.

# %% [markdown]
# ### Pie Chart Showing the Distribution Between Males and Females

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Creating a DataFrame with the provided data
data = {
    'number': [11, 18, 13, 13, 13, 7, 11, 5, 13, 9, 14, 12, 14, 14, 13, 16, 13, 13, 13, 13, 13, 14, 16],
    'gender': [2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1],
}

df = pd.DataFrame(data)

# Counting the number of males and females
gender_counts = df['gender'].value_counts()

# Plotting the pie chart
plt.figure(figsize=(8, 8))

# Define a color palette (pink for female, blue for male)
colors = ['#FFB6C1', '#87CEEB']

plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=colors)
plt.title('Distribution of Male and Female')

# show the pie chart
plt.show()

# %% [markdown]
# ##### This pie chart represents how many males and females there are in the dataset relating to the conditions peoples. A visual representation helps readers understand better without any confusion. 1 represents female and 2 represents male.

# %% [markdown]
# ### The Bar Plot Below Shows The Distribution of Males and Females In Age Groups (20-35) and (35-70)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# 'gender' is the column representing gender (1 is female, 2 is male)
# and 'age' is the column representing age in years

# Creating a DataFrame with the provided data
data = {
    'number': [11, 18, 13, 13, 13, 7, 11, 5, 13, 9, 14, 12, 14, 14, 13, 16, 13, 13, 13, 13, 13, 14, 16],
    'gender': [2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1],
    'age': ['35-39', '40-44', '45-49', '25-29', '50-54', '35-39', '20-24', '25-29', '45-49', '45-49',
            '45-49', '40-44', '35-39', '60-64', '55-59', '45-49', '50-54', '40-44', '50-54', '30-34',
            '35-39', '65-69', '30-34']
}

df = pd.DataFrame(data)

# Convert 'age' column to numeric, if not needed, skip this step
df['age'] = df['age'].apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x.split('>')[1]))

# Create a new column 'age group' based on age
df['age_group'] = pd.cut(df['age'], bins=[20, 35, 70], labels=['20-35', '35-70'], right=False)

# Bar plot for the distribution of males and females in each age group
plt.figure(figsize=(12, 8))
sns.countplot(x='age_group', hue='gender', data=df)
plt.title('Distribution of Males and Females in Age Groups')
plt.xlabel('Age Group (20-35) & (35-70)')
plt.ylabel('Count (female and male)')
plt.show()

# %% [markdown]
# #### This graph shows the difference between males and females in the two groups. As you can see, there is a significant difference between the two. The age group consisting with males and females between (35-70) is way larger than the age group of (20-35). What does this mean?
#
# As people get older, they often find themselves spending time alone. According to the National Institute of Aging, studied show that loneliness and social isolation are assiociated with higher rates of depression.
#
# Younger people often times are busy with their friends and hobbies, which fills the void of loneliness.

# %%
import pandas as pd

# 'gender' is the column representing gender (1 is female, 2 is male)
# and 'age' is the column representing age in years

# Creating a DataFrame with the provided data
data = {
    'number': [11, 18, 13, 13, 13, 7, 11, 5, 13, 9, 14, 12, 14, 14, 13, 16, 13, 13, 13, 13, 13, 14, 16],
    'gender': [2, 2, 1, 2, 2, 1, 1, 2, 2, 2, 1, 2, 2, 1, 2, 1, 1, 2, 2, 1, 2, 2, 1],
    'age': ['35-39', '40-44', '45-49', '25-29', '50-54', '35-39', '20-24', '25-29', '45-49', '45-49',
            '45-49', '40-44', '35-39', '60-64', '55-59', '45-49', '50-54', '40-44', '50-54', '30-34',
            '35-39', '65-69', '30-34']
}

df = pd.DataFrame(data)

# Convert 'age' column to numeric, if not needed, skip this step
df['age'] = df['age'].apply(lambda x: int(x.split('-')[0]) if '-' in x else int(x.split('>')[1]))

# Create a new column 'age group' based on age
df['age_group'] = pd.cut(df['age'], bins=[20, 35, 70], labels=['20-35', '35-70'], right=False)

# Group by 'age group' and 'gender' and calculate the count for each group
summary_table = df.groupby(['age_group', 'gender']).size().unstack().fillna(0).astype(int)

# Adding a 'totals' column
summary_table['Total'] = summary_table.sum(axis=1)

# Displaying the summary table
print(summary_table)
# Out:
# gender     1   2  Total
# age_group
# 20-35      3   2      5
# 35-70      6  12     18

# %% [markdown]
# #### This summary table shows us exactly how many males and females there are in the both age groups. 1 represents female and 2 represents male. In total, we have 18 people who were apart of the research.

# %% [markdown]
# ## Discussion/Conclusion

# %% [markdown]
# To conclude, we analyzed the difference of the distribution of the gender and age of people with depression. We found out that there is a significant difference between older male and female people between the age group of (35-70) than the younger age group which is (20-35). A hypothesis for this as stated before throughout the report, is that people that fell into the age group of (35-70) often find themselves spending time alone and have no social interaction with people. Younger people still go out and hang out with their friends which keeps them busy, leaving no thought of feeling lonely. The bar chart also shows us that males experience depression more than females do. In the younger age group (20-35), females were suffering with depression more than males. According to a study conducted by MayoClinic, the higher rate of depression in younger females is not due to the biology factor alone. Some factors that increase the risk of depression in women include: work overload, sexual/physical abuse, unequal power, etc. Life cicumstances and cultural factors can playa role too. Although men can face these factors as well, it is usually at a lower rate.

# %% [markdown]
# ## References

# %% [markdown]
# 1. https://www.kaggle.com/datasets/arashnic/the-depression-dataset
# 2. Pandas library to import excel file
# 3. Seaborn library to plot visualization
# 4. matplotlib.pyplot to help decorate plots, graphs, table
# 5. ChatGpt, to formulate the question used to analyze the dataset. Prompt was: I plugged my dataset in and asked it "This is the data set i copied from excel for you to analyze using the given requirements above. What question can we pull from this?"
# 6. https://www.mayoclinic.org/diseases-conditions/depression/in-depth/depression/art20047725#:~:text=The%20higher%20rate%20of%20depression,usually%20at%20a%20lower%20rate.
# 7. https://matplotlib.org/2.0.2/users/pyplot_tutorial.html
# 8. https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet
# 9. https://www.nia.nih.gov/health/mental-and-emotional-health/depression-and-older-adults#:~:text=Everyone%20needs%20social%20connections%20to,with%20higher%20rates%20of%20depression.
# 10. %matplotlib inline to ensure plot is displayed inline
